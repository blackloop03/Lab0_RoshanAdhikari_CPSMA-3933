# %% [markdown]
# <a href="https://colab.research.google.com/github/blackloop03/Lab0_RoshanAdhikari_CPSMA-3933/blob/main/Project_Assignments/RegressionAssignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Regression Assignment

# %% [markdown]
# I want you to practice some regression and analyzing your results.  Utilize this document to load data directly.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression, LogisticRegression

# %% [markdown]
# # Linear Regression

# %% [markdown]
# Fit goals vs points in a linear regression.  Fit a multiple regression on goals and assists vs points.  What do you notice about these two fits.
# https://raw.githubusercontent.com/nurfnick/Data_Sets_For_Stats/master/CuratedDataSets/hockey.csv

# %%
df = pd.read_csv('https://raw.githubusercontent.com/nurfnick/Data_Sets_For_Stats/master/CuratedDataSets/hockey.csv')
df.head()
# Out:
#    Rk                       Player  Age   Tm Pos  GP   G   A  PTS  +/-  ...  \
# 0   1  Justin Abdelkader\abdelju01   31  DET  LW  71   6  13   19  -14  ...
# 1   2       Pontus Aberg\abergpo01   25  TOT  LW  59  12  13   25  -14  ...
# 2   2       Pontus Aberg\abergpo01   25  ANA  LW  37  11   8   19  -10  ...
# 3   2       Pontus Aberg\abergpo01   25  MIN  LW  22   1   5    6   -4  ...
# 4   3     Vitaly Abramov\abramvi01   20  OTT  RW   1   0   0    0   -3  ...
#
#    SH.1    S    S%   TOI   ATOI  BLK  HIT  FOW  FOL   FO%
# 0     0   95   6.3  1093  15:24   34  185   52   51  50.5
# 1     0  101  11.9   861  14:36   11   45    2   17  10.5
# 2     0   74  14.9   578  15:37    7   31    2    9  18.2
# 3     0   27   3.7   283  12:52    4   14    0    8   0.0
# 4     0    0   NaN    14  13:52    1    0    0    0   NaN
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Single Linear Regression
# ### With Goal  (G)  as X

# %%
x1 = np.array(df[['G']])
y = np.array(df.PTS)

# %%
model1 = LinearRegression().fit(x1, y)
print("Score (R²) with Goals only:", model1.score(x1, y))
# Out:
# Score (R²) with Goals only: 0.8461669386312143

# %% [markdown]
# ### Conclusion
# So here in the single linear regression, I have tested with Goals vs Points.
# here the R^2 score is 0.8461

# %% [markdown]
# ### With A as X

# %%
x2 = np.array(df[['A']])
y = np.array(df.PTS)

# %%
model1 = LinearRegression().fit(x2, y)
print("Score (R²) with Goals only:", model1.score(x2, y))
# Out:
# Score (R²) with Goals only: 0.9315155483607532

# %% [markdown]
# ### Conclusion
# So here in the single linear regression, I have tested with Assists vs Points.
# here the R^2 score is 0.9315

# %% [markdown]
# ## Multiple Linear Regression

# %%
x = np.array(df[['G','A']])
y = np.array(df.PTS)

# %%
model2 = LinearRegression().fit(x, y)
print("Score (R²) with Goals only:", model1.score(x, y))
# Out:
# Score (R²) with Goals only: 1.0

# %% [markdown]
# ### Conclusion
# In multiple linear regression it was tested for goals and assists vs Points.
# Here we have got R^2 score 1.0 which indicates that the model is perfect.

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# Using the 538 Avengers dataset,https://github.com/fivethirtyeight/data/blob/master/avengers/avengers.csv, fit a logistic regression to predict `Death1` (first time a character might die) based on whatever variables you find interesting.  Make a prediction using probabilities on your favorite character.

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/nurfnick/Data_Sets_For_Stats/master/CuratedDataSets/Avengers')
df2.head()
# Out:
#                                                  URL  \
# 0      http://marvel.wikia.com/Henry_Pym_(Earth-616)
# 1  http://marvel.wikia.com/Janet_van_Dyne_(Earth-...
# 2  http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 3  http://marvel.wikia.com/Robert_Bruce_Banner_(E...
# 4   http://marvel.wikia.com/Thor_Odinson_(Earth-616)
#
#                     Name/Alias  Appearances Current?  Gender  \
# 0    Henry Jonathan "Hank" Pym         1269      YES    MALE
# 1               Janet van Dyne         1165      YES  FEMALE
# 2  Anthony Edward "Tony" Stark         3068      YES    MALE
# 3          Robert Bruce Banner         2089      YES    MALE
# 4                 Thor Odinson         2402      YES    MALE
#
#   Probationary Introl Full/Reserve Avengers Intro  Year  Years since joining  \
# 0                 NaN                      Sep-63  1963                   52
# 1                 NaN                      Sep-63  1963                   52
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   URL                          173 non-null    object
#  1   Name/Alias                   163 non-null    object
#  2   Appearances                  173 non-null    int64
#  3   Current?                     173 non-null    object
#  4   Gender                       173 non-null    object
#  5   Probationary Introl          15 non-null     object
#  6   Full/Reserve Avengers Intro  159 non-null    object
#  7   Year                         173 non-null    int64
#  8   Years since joining          173 non-null    int64
#  9   Honorary                     173 non-null    object
#  10  Death1                       173 non-null    object
#  11  Return1                      69 non-null     object
#  12  Death2                       17 non-null     object
# ...

# %%
X = df2[['Years since joining', 'Appearances', 'Year', 'Current?']].copy()

# Encode 'Current?' (YES=1, NO=0)
X['Current?'] = (X['Current?'] == 'YES').astype(int)

# Target variable: Death1 (YES=1, NO=0)
y = (df2['Death1'] == 'YES').astype(int)

# %%
model = LogisticRegression(max_iter=1000)
model.fit(X, y)
# Out:
# LogisticRegression(max_iter=1000)

# %%
print("Accuracy on dataset:", model.score(X, y))

# Example prediction: probability a character dies
probs = model.predict_proba(X)[:10]  # first 10 characters
print("First 10 prediction probabilities (Survive, Die):")
print(probs)
# Out:
# Accuracy on dataset: 0.6069364161849711
# First 10 prediction probabilities (Survive, Die):
# [[0.56307655 0.43692345]
#  [0.58355981 0.41644019]
#  [0.2323666  0.7676334 ]
#  [0.39971532 0.60028468]
#  [0.34103255 0.65896745]
#  [0.6862639  0.3137361 ]
#  [0.18071833 0.81928167]
#  [0.52452758 0.47547242]
#  [0.65732571 0.34267429]
#  [0.57274531 0.42725469]]

# %%
# Select Hank Pym
hank = df2[df2['Name/Alias'].str.contains("Janet van Dyne", na=False)][['Years since joining', 'Appearances', 'Year', 'Current?']].copy()

# Encode 'Current?' same way as training
hank['Current?'] = (hank['Current?'] == 'YES').astype(int)

print("Janet van Dyne probability (Survive, Die):")
print(model.predict_proba(hank))
# Out:
# Janet van Dyne probability (Survive, Die):
# [[0.58355981 0.41644019]]

# %%
plt.scatter(df['Appearances'],df['Death1'])

# %% [markdown]
# # Find Your Own Regression
#
# I have compiled olympic 100m dash records from a wikipedia page https://en.wikipedia.org/wiki/100_metres_at_the_Olympics.  Use this data and fit a regression of some type for prediciting `Time`.  Justify your model used in words and pictures. Predict the new Olympic Record for 2024 and 2300.  Describe in words the validity of your predictions.

# %%
df3 = pd.read_csv('https://raw.githubusercontent.com/nurfnick/Data_Sets_For_Stats/master/CuratedDataSets/100mOlympicRecords.csv')

df3.head(20)
# Out:
#     Time            Athlete               Nation  Games            Round  \
# 0   12.2       Francis Lane  United States (USA)   1896           Heat 1
# 1   12.2      Thomas Curtis  United States (USA)   1896           Heat 2
# 2   11.8          Tom Burke  United States (USA)   1896           Heat 3
# 3   11.4      Arthur Duffey  United States (USA)   1900           Heat 1
# 4   11.4   Walter Tewksbury  United States (USA)   1900           Heat 2
# 5   10.8       Frank Jarvis  United States (USA)   1900           Heat 3
# 6   10.8   Walter Tewksbury  United States (USA)   1900     Semi-final 2
# 7   10.8       James Rector  United States (USA)   1908          Heat 15
# 8   10.8      Reggie Walker   South Africa (RSA)   1908     Semi-final 1
# 9   10.8       James Rector  United States (USA)   1908     Semi-final 3
# 10  10.8      Reggie Walker   South Africa (RSA)   1908            Final
# 11  10.8       David Jacobs  Great Britain (GBR)   1912          Heat 10
# ...

# %%
df3.shape
# Out:
# (76, 7)

# %% [markdown]
# ## Understanding data
#
# Here I have taken out the unique items from major columns to understand what kind of data are there in the csv file

# %%
print("Unique values in Gender column:")
print(df3['Gender'].unique())


print("\nUnique values in Nation column:")
print(df3['Nation'].unique())


print("\nUnique values in Year column:")
print(df3['Games'].unique())


print(df3['Round'].unique())
# Out:
# Unique values in Gender column:
# ['Men' 'Women']
#
# Unique values in Nation column:
# ['United States\xa0(USA)' 'South Africa\xa0(RSA)' 'Great Britain\xa0(GBR)'
#  'Canada\xa0(CAN)' 'Germany\xa0(GER)' 'West Germany\xa0(FRG)'
#  'Cuba\xa0(CUB)' 'Jamaica\xa0(JAM)' 'Japan\xa0(JPN)' 'Poland\xa0(POL)'
#  'Netherlands\xa0(NED)' 'Australia\xa0(AUS)' 'East Germany\xa0(GDR)']
#
# Unique values in Year column:
# [1896 1900 1908 1912 1924 1928 1932 1936 1948 1956 1960 1964 1968 1988
#  1996 2008 2012 1952 1972 1976 1984 2021]
# ['Heat 1' 'Heat 2' 'Heat 3' 'Semi-final 2' 'Heat 15' 'Semi-final 1'
#  'Semi-final 3' 'Final' 'Heat 10' 'Heat 16' 'Quarter-final 4'
#  'Quarter-final 1' 'Quarter-final 2' 'Heat 4' 'Heat 6' 'Heat 7' 'Heat 9'
#  'Heat 8' 'Quarter-final 3']

# %% [markdown]
# ## Cleaning Data and Feature Engineering
#
#
# The time variable is to be predicted, So that I have removed all the rows that has null in time column.
# ### Feature Engineering
#
# Here feature engineering has also been done to select only the relevant features that to be used in the prediction model.
#
# The feature engineering is done on hit and trial basis and common sense. It would have been better If I had used Co - relation matrix for this.
# But the useful features are in the categrorial values so, it was not done.

# %%
# Drop rows with missing target
df3 = df3.dropna(subset=['Time'])

# Select predictors
features = ['Nation', 'Games', 'Round', 'Gender']
X = df3[features]

# %%
df3.columns
# Out:
# Index(['Time', 'Athlete', 'Nation', 'Games', 'Round', 'Date', 'Gender',
#        'Year'],
#       dtype='object')

# %% [markdown]
# ### Encoding
# The categorial values are encoded to the numerical values as the model can only read the numerical values. Here I have used shortcut to encode all values at onece.
#
# The best practice would be to use different encoding mechanism as per the dataset.

# %%
# Define categorical + numerical features
cat_features = ['Nation', 'Round', 'Gender']
num_features = ['Games']

# Encode categorical
X_cat = pd.get_dummies(df3[cat_features].astype(str), drop_first=True)

# Keep Games numeric
X_num = df3[num_features]

# Combine
X_encoded = pd.concat([X_num, X_cat], axis=1)

# Target
y = df3['Time']

# %% [markdown]
# ## Model Preperation
#
# The multiple linear regression model is prepared using the variable we discussesd above vs. the time taken
#
# Here R^2 score is also calculated to find out the accuracy of the model.

# %%
lin_model = LinearRegression()
lin_model.fit(X_encoded, y)
y_pred = lin_model.predict(X_encoded)
print("R² score:", r2_score(y, y_pred))
# Out:
# R² score: 0.9424830212408771

# %% [markdown]
# ## Testing and predicting
# The prediction is made using the trained linear regression model.
# We fixed values for Nation, Gender, and Round (kept constant), and only changed the Games year to 2024 and 2300.
# This way, the model estimates the Olympic record for these years while holding other factors constant.

# %%
future = pd.DataFrame({
    'Games': [2024, 2300],
    'Nation': ['United States (USA)', 'United States (USA)'],
    'Round': ['Final', 'Final'],
    'Gender': ['Men', 'Men']
})


future_cat = pd.get_dummies(future[['Nation','Round','Gender']].astype(str))
future_num = future[['Games']]


future_encoded = pd.concat([future_num, future_cat], axis=1).reindex(columns=X_encoded.columns, fill_value=0)

# Predict
preds = lin_model.predict(future_encoded)

print("Predicted Olympic Record in Games 2024:", preds[0])
print("Predicted Olympic Record in Games 2300:", preds[1])
# Out:
# Predicted Olympic Record in Games 2024: 8.716841808644183
# Predicted Olympic Record in Games 2300: 2.7648338990748442

# %%
# Out:
# Index(['Time', 'Athlete', 'Nation', 'Games', 'Round', 'Date', 'Gender'], dtype='object')

# %%
import matplotlib.pyplot as plt

# Get predictions on training set
y_pred = lin_model.predict(X_encoded)

# Plot actual vs predicted
plt.figure(figsize=(8,6))
plt.scatter(y, y_pred, alpha=0.6, color="blue", edgecolor="k")
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'r--', lw=2)  # perfect fit line
plt.xlabel("Actual Times")
plt.ylabel("Predicted Times")
plt.title("Actual vs Predicted Olympic 100m Times")
plt.show()
